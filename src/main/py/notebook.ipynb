# %%
# %run load-data.py

# %%
resources
# Out:
#                   name_en          name_fr color_en color_fr
# color_en
# brown            houshold         ménagers    brown   marron
# yellow    paper/cardboard  papiers/cartons   yellow    jaune
# blue            packaging       emballages     blue     bleu
# white               glass            verre    white    blanc
# green           vegetable         végétaux    green     vert
# mauve            chemical        chimiques    mauve    mauve
# red             hospitals         hopitaux      red    rouge
# black             nuclear       nucléaires    black     noir

# %%
contracts
# Out:
#         base_price  duration  count  \
# kind
# mix              5        10      4
# mix             10        10      4
# sorted           5        10      4
# sorted          10         5      2
# sorted          15         5      2
# sorted           0        10      2
# sorted          10         5      2
# sorted          20        10      2
# sorted          50        10      2
#
#                                                  shipping
# kind
# mix     {'brown': 1, 'yellow': 1, 'blue': 1, 'white': ...
# mix     {'yellow': 1, 'blue': 1, 'white': 1, 'green': ...
# sorted                                       {'brown': 5}
# sorted                                      {'yellow': 5}
# sorted                                        {'blue': 5}
# sorted                                       {'white': 5}
# sorted                                       {'green': 5}
# sorted                                       {'mauve': 3}
# sorted                                       {'black': 1}

# %%
facilities
# Out:
#                  price  operating_cost lifetime  count  capacity  \
# type
# storage             20               5        -      2        10
# storage             10               4        -      2        20
# storage             10               3        -      2        10
# storage             10               2        -      2        10
# storage             10               4        -      2        10
# storage             10               2        -      2        10
# storage             10               2        -      2         5
# storage             50              10        -      2         5
# decontamination     20               2        ?      3         2
# incineration        10               2        ?      3         2
# incineration        30               1        ?      3         5
# recycling           10               1        ?      3         3
# recycling           30               2        ?      3         6
# ...

# %%
trade
# Out:
#            yellow  blue  white  green
# [0, 5]          5     8      7      3
# [6, 10]         4     6      6      2
# [11, 15]        3     4      5      2
# [16, 999]       2     2      4      1
